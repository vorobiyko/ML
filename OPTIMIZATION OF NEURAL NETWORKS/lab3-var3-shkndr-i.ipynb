# %% [markdown]
# Shkinder Ivan ПК-21 Variant 3

# %% [markdown]
# 1. Завантажте набір даних.

# %%
# Для роботи з даними
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split

# Для роботи з Keras
from tensorflow.keras.models import Sequential # модель прямого розповсюдження
from tensorflow.keras.layers import Dense # повнозв'язні прошарки

# %%
data = pd.read_csv("./clients_b.csv")

# %% [markdown]
# 2. Виведіть заголовок таблиці (перші 5 записів).

# %%
data.head()
# Out:
#    month  credit_amount  credit_term  age     sex  \
# 0      1          28000           18   36    male
# 1      1          14000           10   25  female
# 2      1           8500            6   28    male
# 3      1           8000           12   25  female
# 4      1          15500           10   25  female
#
#                      education          product_type  having_children_flg  \
# 0  Secondary special education           Cell phones                    1
# 1  Secondary special education           Cell phones                    0
# 2  Secondary special education           Cell phones                    0
# 3          Secondary education  Household appliances                    0
# 4          Secondary education  Household appliances                    0
#
#    region  income family_status  phone_operator  is_client  bad_client_target
# 0       2   16000       Another               2          0                  1
# 1       2   24000       Another               1          1                  1
# 2       2   19000     Unmarried               3          0                  1
# 3       2   11000       Married               3          1                  1
# 4       2   19000       Another               1          1                  1

# %% [markdown]
# 3. В якому форматі мітки класів?
# int64

# %%
column_names = data.keys().values.tolist()
a = data.loc[0]

for i in range(len(column_names)):
    typeRow = type( a[column_names[i]])
    print(column_names[i],' = ',typeRow)
# Out:
# month  =  <class 'numpy.int64'>
# credit_amount  =  <class 'numpy.int64'>
# credit_term  =  <class 'numpy.int64'>
# age  =  <class 'numpy.int64'>
# sex  =  <class 'str'>
# education  =  <class 'str'>
# product_type  =  <class 'str'>
# having_children_flg  =  <class 'numpy.int64'>
# region  =  <class 'numpy.int64'>
# income  =  <class 'numpy.int64'>
# family_status  =  <class 'str'>
# phone_operator  =  <class 'numpy.int64'>
# is_client  =  <class 'numpy.int64'>
# bad_client_target  =  <class 'numpy.int64'>

# %% [markdown]
# 4. В якому форматі характеристики об’єктів? Чи є характеристики у вигляді
# тексту? Якщо так, факторизувати дані в таких стовпцях.

# %%
to_factor = ['sex', 'education', 'product_type', 'family_status']

# %% [markdown]
# 5. Наскільки збалансовані класи?

# %%
data['bad_client_target'].value_counts(normalize=True)
# Out:
# 1    0.506624
# 0    0.493376
# Name: bad_client_target, dtype: float64

# %% [markdown]
# 6. Створити навчальний набір предикторів X та цілей Y. Перетворити мітки класів
# до формату One hot encoding.

# %%
X = data.drop('bad_client_target', axis = 1)
X[to_factor] = X[to_factor].apply(lambda col: pd.factorize(col, sort=True)[0])
X
# Out:
#       month  credit_amount  credit_term  age  sex  education  product_type  \
# 0         1          28000           18   36    1          5             3
# 1         1          14000           10   25    0          5             3
# 2         1           8500            6   28    1          5             3
# 3         1           8000           12   25    0          4            13
# 4         1          15500           10   25    0          4            13
# ...     ...            ...          ...  ...  ...        ...           ...
# 3090     12          46500           24   26    1          0             8
# 3091     12          18500            6   32    1          0             3
# 3092     12           6500            6   24    1          5             3
# 3093     12           5500           12   21    1          1             3
# 3094     12         116000           24   34    1          0             5
#
#       having_children_flg  region  income  family_status  phone_operator  \
# 0                       1       2   16000              0               2
# 1                       0       2   24000              0               1
# 2                       0       2   19000              2               3
# 3                       0       2   11000              1               3
# 4                       0       2   19000              0               1
# ...                   ...     ...     ...            ...             ...
# 3090                    0       2   51000              0               2
# 3091                    1       2   46000              0               1
# 3092                    0       2   18000              0               0
# 3093                    0       2   15000              0               1
# 3094                    1       2   41000              0               2
#
#       is_client
# 0             0
# 1             1
# 2             0
# 3             1
# 4             1
# ...         ...
# 3090          1
# 3091          1
# 3092          1
# 3093          1
# 3094          0
#
# [3095 rows x 13 columns]

# %%
Y = pd.get_dummies(data.bad_client_target, prefix='bad client target')
Y
# Out:
#       bad client target_0  bad client target_1
# 0                       0                    1
# 1                       0                    1
# 2                       0                    1
# 3                       0                    1
# 4                       0                    1
# ...                   ...                  ...
# 3090                    1                    0
# 3091                    1                    0
# 3092                    1                    0
# 3093                    1                    0
# 3094                    1                    0
#
# [3095 rows x 2 columns]

# %% [markdown]
# 7. Розбити набір даних на навчальну та тестову множини.

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.15)

# %% [markdown]
# 8. Стандартизувати предиктори X.

# %%
mean = X_train.mean(axis=0)
std = X_train.std(axis=0)

X_train -= mean
X_train /= std
X_test -= mean
X_test /= std

# %% [markdown]
# 9. Створити модель нейронної мережі прямого розповсюдження. Обрати
# архітектуру, активаційні функції, оптимізатор, критерії якості та метрики. Якщо
# даних мало, під час навчання не використовувати валідаційну множину.

# %%
model = Sequential()
model.add(Dense(50, input_dim=X_train.shape[1], activation="relu"))
model.add(Dense(25, activation="relu"))
model.add(Dense(2, activation="softmax"))

# %% [markdown]
# 10. Навчити нейронну мережу (кілька разів?).

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
history = model.fit(X_train, Y_train, epochs=50,validation_split=0.15,  batch_size=16, verbose=2)
# Out:
# Epoch 1/50
# 140/140 - 1s - loss: 0.6318 - accuracy: 0.6362 - val_loss: 0.5805 - val_accuracy: 0.6810
# Epoch 2/50
# 140/140 - 0s - loss: 0.5743 - accuracy: 0.7110 - val_loss: 0.5406 - val_accuracy: 0.7266
# Epoch 3/50
# 140/140 - 0s - loss: 0.5371 - accuracy: 0.7360 - val_loss: 0.5138 - val_accuracy: 0.7468
# Epoch 4/50
# 140/140 - 0s - loss: 0.5055 - accuracy: 0.7539 - val_loss: 0.4893 - val_accuracy: 0.7646
# Epoch 5/50
# 140/140 - 0s - loss: 0.4809 - accuracy: 0.7660 - val_loss: 0.4698 - val_accuracy: 0.7772
# Epoch 6/50
# 140/140 - 0s - loss: 0.4563 - accuracy: 0.7875 - val_loss: 0.4621 - val_accuracy: 0.8076
# Epoch 7/50
# 140/140 - 0s - loss: 0.4327 - accuracy: 0.8063 - val_loss: 0.4452 - val_accuracy: 0.8152
# Epoch 8/50
# 140/140 - 0s - loss: 0.4116 - accuracy: 0.8277 - val_loss: 0.4271 - val_accuracy: 0.8203
# Epoch 9/50
# 140/140 - 0s - loss: 0.3931 - accuracy: 0.8353 - val_loss: 0.4053 - val_accuracy: 0.8278
# Epoch 10/50
# 140/140 - 0s - loss: 0.3721 - accuracy: 0.8474 - val_loss: 0.3914 - val_accuracy: 0.8557
# Epoch 11/50
# 140/140 - 0s - loss: 0.3520 - accuracy: 0.8595 - val_loss: 0.3855 - val_accuracy: 0.8532
# Epoch 12/50
# 140/140 - 0s - loss: 0.3338 - accuracy: 0.8729 - val_loss: 0.3752 - val_accuracy: 0.8506
# Epoch 13/50
# 140/140 - 0s - loss: 0.3180 - accuracy: 0.8846 - val_loss: 0.3749 - val_accuracy: 0.8532
# Epoch 14/50
# 140/140 - 0s - loss: 0.3009 - accuracy: 0.8881 - val_loss: 0.3419 - val_accuracy: 0.8709
# Epoch 15/50
# 140/140 - 0s - loss: 0.2857 - accuracy: 0.9002 - val_loss: 0.3394 - val_accuracy: 0.8835
# Epoch 16/50
# 140/140 - 0s - loss: 0.2705 - accuracy: 0.9038 - val_loss: 0.3173 - val_accuracy: 0.8810
# Epoch 17/50
# 140/140 - 0s - loss: 0.2569 - accuracy: 0.9123 - val_loss: 0.3142 - val_accuracy: 0.8861
# Epoch 18/50
# 140/140 - 0s - loss: 0.2480 - accuracy: 0.9168 - val_loss: 0.3048 - val_accuracy: 0.8911
# Epoch 19/50
# 140/140 - 0s - loss: 0.2372 - accuracy: 0.9217 - val_loss: 0.2950 - val_accuracy: 0.8962
# Epoch 20/50
# 140/140 - 0s - loss: 0.2219 - accuracy: 0.9315 - val_loss: 0.2988 - val_accuracy: 0.8937
# Epoch 21/50
# 140/140 - 0s - loss: 0.2094 - accuracy: 0.9374 - val_loss: 0.2861 - val_accuracy: 0.9038
# Epoch 22/50
# 140/140 - 0s - loss: 0.2007 - accuracy: 0.9387 - val_loss: 0.2784 - val_accuracy: 0.9013
# Epoch 23/50
# 140/140 - 0s - loss: 0.1908 - accuracy: 0.9441 - val_loss: 0.2800 - val_accuracy: 0.9165
# Epoch 24/50
# 140/140 - 0s - loss: 0.1843 - accuracy: 0.9472 - val_loss: 0.2629 - val_accuracy: 0.9114
# Epoch 25/50
# 140/140 - 0s - loss: 0.1712 - accuracy: 0.9570 - val_loss: 0.2830 - val_accuracy: 0.8962
# Epoch 26/50
# 140/140 - 0s - loss: 0.1649 - accuracy: 0.9562 - val_loss: 0.2614 - val_accuracy: 0.9190
# Epoch 27/50
# 140/140 - 0s - loss: 0.1557 - accuracy: 0.9593 - val_loss: 0.2527 - val_accuracy: 0.9266
# Epoch 28/50
# 140/140 - 0s - loss: 0.1558 - accuracy: 0.9579 - val_loss: 0.2706 - val_accuracy: 0.9063
# Epoch 29/50
# 140/140 - 0s - loss: 0.1461 - accuracy: 0.9611 - val_loss: 0.2520 - val_accuracy: 0.9114
# Epoch 30/50
# 140/140 - 0s - loss: 0.1359 - accuracy: 0.9669 - val_loss: 0.2549 - val_accuracy: 0.9139
# Epoch 31/50
# 140/140 - 0s - loss: 0.1314 - accuracy: 0.9647 - val_loss: 0.2403 - val_accuracy: 0.9291
# Epoch 32/50
# 140/140 - 0s - loss: 0.1251 - accuracy: 0.9736 - val_loss: 0.2795 - val_accuracy: 0.9063
# Epoch 33/50
# 140/140 - 0s - loss: 0.1214 - accuracy: 0.9696 - val_loss: 0.2401 - val_accuracy: 0.9165
# Epoch 34/50
# 140/140 - 0s - loss: 0.1130 - accuracy: 0.9745 - val_loss: 0.2515 - val_accuracy: 0.9114
# Epoch 35/50
# 140/140 - 0s - loss: 0.1067 - accuracy: 0.9758 - val_loss: 0.2335 - val_accuracy: 0.9190
# Epoch 36/50
# 140/140 - 0s - loss: 0.1026 - accuracy: 0.9763 - val_loss: 0.2345 - val_accuracy: 0.9241
# Epoch 37/50
# 140/140 - 0s - loss: 0.0990 - accuracy: 0.9767 - val_loss: 0.2258 - val_accuracy: 0.9291
# Epoch 38/50
# 140/140 - 0s - loss: 0.0921 - accuracy: 0.9808 - val_loss: 0.2307 - val_accuracy: 0.9190
# Epoch 39/50
# 140/140 - 0s - loss: 0.0888 - accuracy: 0.9812 - val_loss: 0.2299 - val_accuracy: 0.9241
# Epoch 40/50
# 140/140 - 0s - loss: 0.0861 - accuracy: 0.9808 - val_loss: 0.2148 - val_accuracy: 0.9443
# Epoch 41/50
# 140/140 - 0s - loss: 0.0793 - accuracy: 0.9843 - val_loss: 0.2256 - val_accuracy: 0.9316
# Epoch 42/50
# 140/140 - 0s - loss: 0.0765 - accuracy: 0.9852 - val_loss: 0.2402 - val_accuracy: 0.9190
# Epoch 43/50
# 140/140 - 0s - loss: 0.0709 - accuracy: 0.9857 - val_loss: 0.2364 - val_accuracy: 0.9291
# Epoch 44/50
# 140/140 - 0s - loss: 0.0705 - accuracy: 0.9888 - val_loss: 0.2374 - val_accuracy: 0.9266
# Epoch 45/50
# 140/140 - 0s - loss: 0.0678 - accuracy: 0.9848 - val_loss: 0.2313 - val_accuracy: 0.9316
# Epoch 46/50
# 140/140 - 0s - loss: 0.0681 - accuracy: 0.9866 - val_loss: 0.2396 - val_accuracy: 0.9316
# Epoch 47/50
# 140/140 - 0s - loss: 0.0645 - accuracy: 0.9861 - val_loss: 0.2144 - val_accuracy: 0.9418
# Epoch 48/50
# 140/140 - 0s - loss: 0.0602 - accuracy: 0.9866 - val_loss: 0.2297 - val_accuracy: 0.9342
# Epoch 49/50
# 140/140 - 0s - loss: 0.0554 - accuracy: 0.9906 - val_loss: 0.2450 - val_accuracy: 0.9266
# Epoch 50/50
# 140/140 - 0s - loss: 0.0523 - accuracy: 0.9911 - val_loss: 0.2455 - val_accuracy: 0.9291

# %% [markdown]
# 11. Оцінити якість роботи навченої мережі на тестовій множині.

# %%
loss, accuracy = model.evaluate(X_test, Y_test, verbose=0)
print(loss, accuracy)
# Out:
# 0.2186904102563858 0.9376344084739685

# %% [markdown]
# 12. Побудувати графік залежності критерію якості (або метрики) від номеру ітерації
# навчання. Проаналізувати графік і, за потреби, перенавчити мережу, врахувавши
# отриману інформацію.

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %% [markdown]
# 13. Подати на вхід навченої мережі довільний зразок із тестової вибірки. За
# результатами вивести наступне повідомлення: «Передбачено клас {мітка класу}
# з достовірністю {Р}%».

# %%
sample = X_test[0:1]
prediction = model.predict(sample)
print(prediction)
score = np.max(prediction)
prediction = np.argmax(prediction)

print(f'Передбачено: {prediction} з достовірністю {score*100:.2f}%', f'Повинно бути: {np.argmax(Y_test[0:1])}', sep='\n')
# Out:
# [[5.1399448e-04 9.9948597e-01]]
# Передбачено: 1 з достовірністю 99.95%
# Повинно бути: 1

# %%
model.save('mobile_price.h5')
